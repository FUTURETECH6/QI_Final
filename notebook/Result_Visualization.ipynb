# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## LGB

# %% [markdown]
# ## DNN

# %%
# \w*\s\d*/\d*\n\s-\s\d*s\s-\s\w*: \d*.\d*\s-\s\w*: \d*.\d*\s*\n\w*-\w*: \d*.\d*\s-\s\w*-\w*:\s
dnn_res = np.array([ \
    [0.7678, 0.7743, 0.7772, 0.7795, 0.7783, 0.7814, 0.7799, 0.7799, 0.7797, 0.7783],
    [0.7588, 0.7637, 0.7685, 0.7702, 0.7718, 0.77, 0.7683, 0.7672, 0.7677, 0.7677],
    [0.7639, 0.7708, 0.7739, 0.7762, 0.7759, 0.7703, 0.7743, 0.776, 0.7743, 0.7739],
    [0.7619, 0.7699, 0.771, 0.7717, 0.7728, 0.7722, 0.7757, 0.775, 0.7753, 0.7712],
    [0.7593, 0.7649, 0.7665, 0.7704, 0.7698, 0.7694, 0.7685, 0.7671, 0.767, 0.7659],
    [0.7574, 0.7624, 0.7619, 0.7681, 0.7686, 0.772, 0.7697, 0.7693, 0.7694, 0.7684],
    [0.7636, 0.7703, 0.7719, 0.7669, 0.7716, 0.7711, 0.7694, 0.7689, 0.7691, 0.768],
    [0.7644, 0.7776, 0.7794, 0.7779, 0.7811, 0.7812, 0.781, 0.78, 0.7775, 0.7773],
    [0.7672, 0.772, 0.7705, 0.7756, 0.7752, 0.776, 0.7749, 0.7719, 0.775, 0.7735],
    [0.7682, 0.7748, 0.7768, 0.7775, 0.7778, 0.7776, 0.7768, 0.773, 0.7744, 0.7744]])
dnn_table = pd.DataFrame(columns=['KFold', 'Epoch', 'Auc'])
dnn_table['KFold_TestID'] = [i // 10 for i in range(0, 100)]
dnn_table['Epoch'] = [i % 10 + 1 for i in range(0, 100)]
dnn_table['Auc'] = dnn_res.flatten()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(data=dnn_res[:, ::-1].T, cmap='YlGnBu', fmt='.4f', square=True, annot=True, yticklabels=range(10, 0, -1))
plt.xlabel('KFold_TestID', fontsize=14)
plt.ylabel('Epoch', fontsize=14)
plt.savefig('../assets/DNN_Heatmap.svg', format='svg')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.catplot(data=dnn_table, x='KFold_TestID', y='Auc', hue='Epoch', aspect=2, height=6, palette=sns.light_palette("green", n_colors=10))
plt.xlabel('KFold_TestID', fontsize=14)
plt.ylabel('Auc', fontsize=14)
plt.savefig('../assets/Auc-KFold.svg', format='svg')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.pointplot(data=dnn_table, x='Epoch', y='Auc', hue='KFold_TestID', aspect=2, height=6, palette=sns.color_palette('hls', n_colors=10))
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Auc', fontsize=14)
plt.savefig('../assets/Auc-Epoch.svg', format='svg')
plt.show()
